# %%
import numpy as np
import pandas as pd

# %%
years = ["2017", "2019" , "2021", "2023"]
desired_col = ["CONTROL","AGE", "CITSHP", "ENROLL", "FAMLINE", "FAMREL", "GRAD", "FAMTYP", "MAR", "MIL", "MOVE", 
               "MOVERGRP", "PERSONID", "RACE", "RESPONDENT", "SEX", "SPAN"]

for i in years:
    data = pd.read_csv(f"AHS_{i}_metro/person.csv")
    data = data[desired_col]
    for u in range(len(data.columns)):
        if data.iloc[:,u].dtypes == 'O':
            data.iloc[:,u] = data.iloc[:,u].str.replace("'", "")
    data.to_csv(f"AHS_{i}_P_cleaned.csv", index=False)

# %%
desired_col = ["CONTROL", "INTSTATUS", "MGRONSITE", "TENURE", "BLD", "BATHROOMS", "BEDROOMS", "UNITSIZE", "WAHSER", "MOLDBEDRM", 
               "MOLDKITCH","MOLDLROOM", "ROACH", "WALLCRACK", "GRANDHH", "HSHLDTYPE", "MILHH", "MULTIGEN", "NUMPEOPLE",
               "SAMEHHHLD", "HHAGE", "HHENROLL", "HHGRAD", "HHCITSHP","HHMAR", "HHRACE", "HHSEX"]
for i in years:

# %%
data = pd.read_csv("AHS_2017_metro/household.csv")

# %%
data
# Out:
#           CONTROL  TOTROOMS  PERPOVLVL COMTYPE  COMCOST JACPRIMARY JACSECNDRY  \
# 0      '21030112'         7        501     '1'    16692        '0'        '0'
# 1      '21030114'         7        501    '-6'       -6        '0'        '0'
# 2      '21030115'         5         -6    '-6'       -6        '0'        '0'
# 3      '21030116'         4        501     '1'       -9        '0'        '0'
# 4      '21030117'         4         -6    '-6'       -6        '0'        '0'
# ...           ...       ...        ...     ...      ...        ...        ...
# 23079  '21060088'         6         -6    '-6'       -6        '3'        '3'
# 23080  '21060089'         3         -6    '-6'       -6        '0'        '0'
# 23081  '21060090'         7        308    '-6'       -6        '0'        '0'
# 23082  '21060091'         4        277    '-6'       -6        '0'        '0'
# 23083  '21060092'         3         -6    '-6'       -6        '2'        '2'
#
#       JADEQUACY JBATHEXCLU JBATHROOMS  ... PROTAXAMT INSURAMT HOAAMT LOTAMT  \
# 0           '1'        '0'        '0'  ...        -6       75     -6     -6
# 1           '2'        '0'        '0'  ...       162      157      0     -6
# 2           '2'        '0'        '0'  ...        -6       -6     -6     -6
# 3           '1'        '0'        '0'  ...        -6        0     -6     -6
# 4           '2'        '0'        '0'  ...        -6       -6     -6     -6
# ...         ...        ...        ...  ...       ...      ...    ...    ...
# 23079       '2'        '0'        '2'  ...        -6       -6     -6     -6
# 23080       '2'        '0'        '0'  ...        -6       -6     -6     -6
# 23081       '2'        '0'        '0'  ...       272      100      9     -6
# 23082       '2'        '0'        '0'  ...        -6        0     -6     -6
# 23083       '2'        '0'        '2'  ...        -6       -6     -6     -6
#
#       MAINTAMT MORTAMT   HINCP   FINCP REMODAMT TOTHCAMT
# 0           -6      -6  100000  100000       -6     4055
# 1          190      -6  130000  130000        0      495
# 2           -6      -6      -6      -6       -6       -6
# 3           -6      -6   89700   23700       -6      550
# 4           -6      -6      -6      -6       -6       -6
# ...        ...     ...     ...     ...      ...      ...
# 23079       -6      -6      -6      -6       -6       -6
# 23080       -6      -6      -6      -6       -6       -6
# 23081        0     905   45210   45210        0     1626
# 23082       -6      -6   45000   45000       -6     1020
# 23083       -6      -6      -6      -6       -6       -6
#
# [23084 rows x 1089 columns]
